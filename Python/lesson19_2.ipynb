# %%
import pandas as pd
df=pd.read_csv('productstar_df.csv')
df
# Out:
#             id                 shipped_at  order_id    item_total order_state  \
# 0            0  2018-05-20 01:42:14+00:00       557   3243.119268    complete
# 1            1                        NaN      1097   4590.108329    canceled
# 2            2  2017-06-14 03:26:44+00:00      3103  12018.548693    complete
# 3            3  2017-06-12 00:16:40+00:00      3112   2467.022803    complete
# 4            4  2017-05-31 05:23:53+00:00      3201   1461.915164    complete
# ...        ...                        ...       ...           ...         ...
# 474954  474954  2019-01-05 23:01:39+00:00   3642207   2261.725542    complete
# 474955  474955                        NaN   3642208   3234.739393    canceled
# 474956  474956  2019-01-23 05:19:03+00:00   3642213   3621.669987    complete
# 474957  474957  2018-12-26 09:02:33+00:00   3642227   3089.668218    complete
# 474958  474958  2018-12-21 09:49:58+00:00   3642244   4110.140282    complete
#
# ...

# %%
df['completed_at']=pd.to_datetime(df['completed_at'])
df.index
df.dtypes
# Out:
# RangeIndex(start=0, stop=474959, step=1)

# %%
df['year']=df['completed_at'].dt.year
df['month']=df['completed_at'].dt.month
df
# Out:
#             id                 shipped_at  order_id    item_total order_state  \
# 0            0  2018-05-20 01:42:14+00:00       557   3243.119268    complete
# 1            1                        NaN      1097   4590.108329    canceled
# 2            2  2017-06-14 03:26:44+00:00      3103  12018.548693    complete
# 3            3  2017-06-12 00:16:40+00:00      3112   2467.022803    complete
# 4            4  2017-05-31 05:23:53+00:00      3201   1461.915164    complete
# ...        ...                        ...       ...           ...         ...
# 474954  474954  2019-01-05 23:01:39+00:00   3642207   2261.725542    complete
# 474955  474955                        NaN   3642208   3234.739393    canceled
# 474956  474956  2019-01-23 05:19:03+00:00   3642213   3621.669987    complete
# 474957  474957  2018-12-26 09:02:33+00:00   3642227   3089.668218    complete
# 474958  474958  2018-12-21 09:49:58+00:00   3642244   4110.140282    complete
#
# ...

# %%
df_compl=df[df['order_state']=='complete']
df_compl
# Out:
#             id                 shipped_at  order_id    item_total order_state  \
# 0            0  2018-05-20 01:42:14+00:00       557   3243.119268    complete
# 2            2  2017-06-14 03:26:44+00:00      3103  12018.548693    complete
# 3            3  2017-06-12 00:16:40+00:00      3112   2467.022803    complete
# 4            4  2017-05-31 05:23:53+00:00      3201   1461.915164    complete
# 5            5  2017-02-13 00:23:00+00:00      3204   3351.866708    complete
# ...        ...                        ...       ...           ...         ...
# 474952  474952  2018-12-30 06:55:32+00:00   3642200   3689.268464    complete
# 474954  474954  2019-01-05 23:01:39+00:00   3642207   2261.725542    complete
# 474956  474956  2019-01-23 05:19:03+00:00   3642213   3621.669987    complete
# 474957  474957  2018-12-26 09:02:33+00:00   3642227   3089.668218    complete
# 474958  474958  2018-12-21 09:49:58+00:00   3642244   4110.140282    complete
#
# ...

# %%
df_compl
df1=df_compl[(df_compl['year']==2019)&(df_compl['month']==12)]
df1
# Out:
#             id                 shipped_at  order_id   item_total order_state  \
# 202        202  2019-12-15 02:36:33+00:00   3643339  2370.096833    complete
# 217        217  2019-12-18 11:54:39+00:00   3643435  3217.547844    complete
# 283        283  2019-12-27 11:36:21+00:00   3643773  2954.763059    complete
# 459        459  2019-12-13 08:25:56+00:00   3644474  2916.362873    complete
# 706        706  2019-12-10 03:40:39+00:00   3645603  3050.390114    complete
# ...        ...                        ...       ...          ...         ...
# 473822  473822  2019-12-21 09:45:26+00:00   3702418  3960.437584    complete
# 473823  473823  2019-12-18 05:10:22+00:00   3703084  1906.680826    complete
# 473827  473827  2019-12-25 00:53:41+00:00   3706765  5970.278677    complete
# 473830  473830  2019-12-13 06:09:37+00:00   3710547  3856.454736    complete
# 474631  474631  2019-12-22 03:15:00+00:00   3640059  1569.448849    complete
#
# ...

# %%
am1=df1['item_total'].sum()
am1
# Out:
# 172437310.3718201

# %%
df2=df_compl[(df_compl['year']==2018)&(df_compl['month']==12)]
df2
# Out:
#             id                 shipped_at  order_id   item_total order_state  \
# 19          19  2018-12-17 10:26:32+00:00   3642287  3020.441247    complete
# 20          20  2018-12-22 02:25:24+00:00   3642302  2527.483122    complete
# 21          21  2018-12-16 23:17:38+00:00   3642304  3985.041932    complete
# 22          22  2018-12-29 05:46:41+00:00   3642319  1755.222726    complete
# 24          24  2018-12-19 01:55:36+00:00   3642344  8162.850603    complete
# ...        ...                        ...       ...          ...         ...
# 474950  474950  2018-12-31 12:21:45+00:00   3642159  2901.167326    complete
# 474951  474951  2018-12-29 01:35:57+00:00   3642174  2814.919303    complete
# 474952  474952  2018-12-30 06:55:32+00:00   3642200  3689.268464    complete
# 474957  474957  2018-12-26 09:02:33+00:00   3642227  3089.668218    complete
# 474958  474958  2018-12-21 09:49:58+00:00   3642244  4110.140282    complete
#
# ...

# %%
am2=df2['item_total'].sum()
am2
# Out:
# 40189287.74753651

# %%
(am1-am2)/am2
# Out:
# 3.290628673368067

# %%
df3=df_compl[(df_compl['year']==2018)]

# %%
am=df3['user_id'].mean()/df3['user_id'].median()
am
# Out:
# 1.0417313309818101
